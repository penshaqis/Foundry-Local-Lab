# %%
from foundry_local import FoundryLocalManager

manager = FoundryLocalManager()
manager.start_service()

info = manager.get_model_info("phi-3.5-mini")
print(f"Selected model: {info.id}")
print(f"Device: {info.device_type}")
print(f"Provider: {info.execution_provider}")
# Out:
# Selected model: phi-3.5-mini-instruct-qnn-npu:2
# Device: NPU
# Provider: QNNExecutionProvider

# %%
print(f"Version: {info.version}")
print(f"Tool calling or nah?: {info.supports_tool_calling}")
print(f"Publisher: {info.publisher}")
print(f"Prompt Template, if any: {info.prompt_template}")
# Out:
# Version: 2
# Tool calling or nah?: False
# Publisher: Microsoft
# Prompt Template, if any: {'system': '<|system|>Your name is Phi, an AI math expert developed by Microsoft. {Content}<|end|>', 'user': '<|user|>{Content}<|end|>', 'assistant': '<|assistant|>{Content}<|end|>', 'prompt': '<|user|>{Content}<|end|><|assistant|>'}
